# %% [markdown]
# # 🚀 Master Notebook: Unified Free AI Studio
# ### Code Generation | Image Generation (FLUX.1) | Video Generation (LTX-Video) | Automation API
#
# > **Environment:** Google Colab Cloud GPU (T4 / L4 / A100)
# > **Storage:** Mounted 5TB Google Drive (`/content/drive/MyDrive/Funzone_AI_Studio/`)
#
# ---

# %% [markdown]
# ## 📌 Cell 1: Hardware & GPU Verification

# %%
# Check NVIDIA GPU availability
# !nvidia-smi
import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU Name: {torch.cuda.get_device_name(0)}")

# %% [markdown]
# ## 📌 Cell 2: Mount Google Drive for Persistent Model Storage

# %%
from google.colab import drive
import os

drive.mount('/content/drive')

BASE_PATH = '/content/drive/MyDrive/Funzone_AI_Studio'
MODELS_PATH = os.path.join(BASE_PATH, 'models')
OUTPUTS_PATH = os.path.join(BASE_PATH, 'outputs')

os.makedirs(MODELS_PATH, exist_ok=True)
os.makedirs(OUTPUTS_PATH, exist_ok=True)

print(f"✅ Google Drive Mounted Successfully!")
print(f"📁 Base Directory: {BASE_PATH}")
print(f"📦 Models Directory: {MODELS_PATH}")
print(f"🖼️ Outputs Directory: {OUTPUTS_PATH}")

# %% [markdown]
# ## 📌 Cell 3: Install Required Dependencies

# %%
# Install CUDA accelerated llama-cpp, diffusers, transformers, and Gradio/FastAPI
# !pip install -q diffusers transformers accelerate sentencepiece huggingface_hub gradio fastapi uvicorn pyngrok pydantic
# !CMAKE_ARGS="-DGGML_CUDA=on" pip install -q llama-cpp-python
print("✅ All dependencies installed successfully!")

# %% [markdown]
# ## 📌 Cell 4: Verify & Load Python Scripts from Drive/Workspace

# %%
import sys
sys.path.append(BASE_PATH)
print(f"Python Path Updated: {BASE_PATH}")

# %% [markdown]
# ## 📌 Cell 5: Launch Unified Web UI & REST API Server

# %%
# This cell will launch the FastAPI + Gradio server with public shareable URL
# %run {BASE_PATH}/scripts/server_api.py
